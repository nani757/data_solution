# %%
# !pip install pandas
# !python3 --version
# !python3 -m pip install --upgrade pip
# !python3 -m pip install pandas
# !python3 -m pip install polars

# %%
import pandas as pd
import polars as pl

# %%
def read_file_pd(file_path):
    if file_path.endswith('.csv'):
        # File is CSV
        df = pd.read_csv(file_path)
        df.info()
    elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        # File is Excel
        df = pd.read_excel(file_path)
        df.info()
    else:
        # File format not supported
        print("Unsupported file format. Please provide a CSV or Excel file.")
        return None
    
    return df

# Example usage
file_path = "Shark_Tank_India_Dataset.csv"
# file_path = input("Enter the file path: ")
data_frame = read_file_pd(file_path)

if data_frame is not None:
    print("Data successfully loaded:")
    print(data_frame.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
def read_file_Pl(file_path):
    if file_path.endswith('.csv'):
        # File is CSV
        df = pl.read_csv(file_path)
        df.describe()
    elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        # File is Excel
        df = pl.read_excel(file_path)
        df.describe()
    else:
        # File format not supported
        print("Unsupported file format. Please provide a CSV or Excel file.")
        return None
    
    return df

# Example usage
file_path = "Shark_Tank_India_Dataset.csv"
# file_path = input("Enter the file path: ")
data_frame = read_file_Pl(file_path)

if data_frame is not None:
    print("Data successfully loaded:")
    print(data_frame.head())
# Out:
# Data successfully loaded:
# shape: (5, 28)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ episode_n ┆ pitch_num ┆ brand_nam ┆ idea      ┆ … ┆ ghazal_de ┆ total_sha ┆ amount_pe ┆ equity_p │
# │ umber     ┆ ber       ┆ e         ┆ ---       ┆   ┆ al        ┆ rks_inves ┆ r_shark   ┆ er_shark │
# │ ---       ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ted       ┆ ---       ┆ ---      │
# │ i64       ┆ i64       ┆ str       ┆           ┆   ┆ i64       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ i64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ 1         ┆ BluePine  ┆ Frozen    ┆ … ┆ 0         ┆ 3         ┆ 25.0      ┆ 5.333333 │
# │           ┆           ┆ Industrie ┆ Momos     ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
import pandas as pd
import os

def read_file_pd(file_path):
    if file_path.endswith('.csv'):
        # File is CSV
        df = pd.read_csv(file_path)
        df.info()
    elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        # File is Excel
        df = pd.read_excel(file_path)
        df.info()
    else:
        # File format not supported
        print("Unsupported file format. Please provide a CSV or Excel file.")
        return None
    
    return df

def read_file_Pl(file_path):
    if file_path.endswith('.csv'):
        # File is CSV
        df = pl.read_csv(file_path)
        df.info()
    elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        # File is Excel
        df = pl.read_excel(file_path)
        df.info()
    else:
        # File format not supported
        print("Unsupported file format. Please provide a CSV or Excel file.")
        return None
    
    return df

# Example usage
file_path = "Shark_Tank_India_Dataset.csv"
# file_path = input("Enter the file path: ")

# Check dataset size
file_size = os.path.getsize(file_path)
if file_size > 100 * 1024 * 1024:  # 100 megabytes
    data_frame = read_file_Pl(file_path)
else: 
    data_frame = read_file_pd(file_path)

if data_frame is not None:
    print("Data successfully loaded:")
    print(data_frame.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
# !pip install scikit-learn
# Out:
#          _
#      ---(_)
#  _/  ---  \
# (_) |   |
#   \  --- _/
#      ---(_)
# balgopal@balgopal-Aspire-E5-523
# osUbuntu 22.04.2 LTS
# hostAspire E5-523 V1.18
# kernel5.19.0-46-generic
# uptime12m
# pkgs2101
# memory5533M / 7391M
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 4.2 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 2.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 5.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
